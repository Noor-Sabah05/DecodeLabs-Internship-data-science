# %% [markdown]
# ## Task 5 Predictive Model or Insight Project
# **Insight-Based Recommendation System**
#
# Question:
#
# Which products should the business promote?
#
# Instead of ML prediction, build data-driven recommendations:
#
# - Best-selling products
# - Highest revenue products
# - Best referral source
# - Coupon effectiveness
# - Customer segments

# %% [markdown]
# # left as optional
