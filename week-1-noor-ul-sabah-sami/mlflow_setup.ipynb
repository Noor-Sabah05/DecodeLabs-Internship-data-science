# %%
import dagshub
import mlflow

dagshub.init(
    repo_owner="noorsammy32",
    repo_name="DecodeLabs-Internship-data-science",
    mlflow=True
)
# Out:
# Initialized MLflow to track repo "noorsammy32/DecodeLabs-Internship-data-science"
# Repository noorsammy32/DecodeLabs-Internship-data-science initialized!

# %%
with mlflow.start_run(run_name="week1-test-run"):
    mlflow.log_param("dataset", "week1_cleaned")
    mlflow.log_param("task", "eda_and_cleaning")

    mlflow.log_metric("rows", 1200)
    mlflow.log_metric("missing_values", 0)
# Out:
# 🏃 View run week1-test-run at: https://dagshub.com/noorsammy32/DecodeLabs-Internship-data-science.mlflow/#/experiments/0/runs/47caa63ccd744840a4bcda7c5f51f5fd
# 🧪 View experiment at: https://dagshub.com/noorsammy32/DecodeLabs-Internship-data-science.mlflow/#/experiments/0
